# %% [markdown]
# <img src='https://i.imgur.com/RDAD11M.png' width = '200' align = 'right'>
#
# ## *DATA SCIENCE / SECTION 1 / SPRINT 1 / NOTE 1*
#
# ---
#
# # 📝 Assignment

# %% [markdown]
# ## 1.데이터셋 불러오기 연습
#
# 다음 url에서 엑셀 파일을 불러오세요. (pandas excel)
#
# <https://ds-lecture-data.s3.ap-northeast-2.amazonaws.com/stocks/Travel.xlsx>
#
#   - 데이터셋 변수의 이름은 `df1`, `df2`로 저장하세요.
#   - row가 아닌 column에 '매출액', '영업이익' 이 가도록 데이터를 transpose 하세요.
#   - 이후 아래 링크를 참조하여 첫번째 row를 column name으로 설정하세요.
#
# <https://stackoverflow.com/questions/31328861/python-pandas-replacing-header-with-top-row>
#
# - 파일은 2개의 시트로 구성되어 있으며 각각 이름은 `008770`, `035250` 입니다.

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel('Travel.xlsx')
print(df)
# Out:
#         주요재무정보  2019/09\n(IFRS연결)  2019/12\n(IFRS연결)  2020/03\n(IFRS연결)  \
# 0          매출액           14753.00           15440.00            9437.00
# 1         영업이익             574.00             776.00            -668.00
# 2   영업이익(발표기준)             574.00             776.00            -668.00
# 3     세전계속사업이익             376.00             538.00            -925.00
# 4        당기순이익             274.00             380.00            -736.00
# 5    당기순이익(지배)             277.00             380.00            -736.00
# 6   당기순이익(비지배)              -3.00               0.00               0.00
# 7         자산총계           37747.00           35273.00           33188.00
# 8         부채총계           28854.00           26077.00           24813.00
# 9         자본총계            8893.00            9195.00            8375.00
# 10    자본총계(지배)            8889.00            9192.00            8371.00
# 11   자본총계(비지배)               4.00               4.00               4.00
# 12         자본금            2000.00            2000.00            2000.00
# 13    영업활동현금흐름            1652.00            -480.00           -4525.00
# 14    투자활동현금흐름            -284.00            -208.00            -237.00
# 15    재무활동현금흐름            -900.00            1230.00            1288.00
# 16       CAPEX             159.00             109.00             155.00
# 17         FCF            1493.00            -589.00           -4680.00
# 18      이자발생부채           19035.00           15615.00           17505.00
# 19       영업이익률               3.89               5.03              -7.08
# 20        순이익률               1.86               2.46              -7.80
# 21      ROE(%)              13.18              20.16               5.39
# 22      ROA(%)               3.62               5.81               1.25
# 23        부채비율             324.45             283.59             296.28
# 24       자본유보율             395.10             411.78             368.36
# 25      EPS(원)             692.00             950.00           -1839.00
# 26      PER(배)              31.19              21.40              63.76
# 27      BPS(원)           23484.00           24282.00           22114.00
# 28      PBR(배)               3.67               3.74               3.19
# 29    현금DPS(원)               0.00             350.00                NaN
# 30     현금배당수익률                NaN                NaN                NaN
# 31   현금배당성향(%)               0.00              34.94               0.00
#
#     2020/06\n(IFRS연결)  2020/09\n(IFRS연결)  2020/12(E)\n(IFRS연결)  \
# 0             5230.00            8795.00               9980.00
# 1             -634.00            -198.00                 50.00
# 2             -634.00            -198.00                   NaN
# 3             -819.00            -366.00               -109.00
# 4             -677.00            -285.00               -100.00
# 5             -678.00            -285.00               -100.00
# 6                1.00               0.00                   NaN
# 7            33039.00           32683.00              32388.00
# 8            25364.00           25318.00              25171.00
# 9             7676.00            7365.00               7216.00
# 10            7671.00            7360.00               7263.00
# 11               5.00               5.00                   NaN
# 12            2000.00            2000.00               2000.00
# 13             879.00            3104.00                   NaN
# 14            -856.00           -1388.00                   NaN
# 15             448.00            -882.00                   NaN
# 16              90.00             129.00                   NaN
# 17             789.00            2975.00                   NaN
# 18           18933.00           17755.00                   NaN
# 19             -12.13              -2.25                  0.50
# 20             -12.95              -3.24                 -1.01
# 21              -9.31             -16.22                   NaN
# 22              -2.14              -3.74                   NaN
# 23             330.45             343.77                348.79
# 24             334.46             320.21                   NaN
# 25           -1695.00            -712.00               -251.00
# 26                NaN                NaN                   NaN
# 27           20265.00           19444.00              19187.00
# 28               3.50               3.91                  4.22
# 29                NaN                NaN                   NaN
# 30                NaN                NaN                   NaN
# 31               0.00                NaN                   NaN
#
#     2021/03(E)\n(IFRS연결)  2021/06(E)\n(IFRS연결)
# 0                9761.00               9820.00
# 1                 144.00                265.00
# 2                    NaN                   NaN
# 3                  14.00                172.00
# 4                  71.00                214.00
# 5                  53.00                123.00
# 6                    NaN                   NaN
# 7                    NaN                   NaN
# 8                    NaN                   NaN
# 9                    NaN                   NaN
# 10                   NaN                   NaN
# 11                   NaN                   NaN
# 12                   NaN                   NaN
# 13                   NaN                   NaN
# 14                   NaN                   NaN
# 15                   NaN                   NaN
# 16                   NaN                   NaN
# 17                   NaN                   NaN
# 18                   NaN                   NaN
# 19                  1.47                  2.70
# 20                  0.73                  2.18
# 21                   NaN                   NaN
# 22                   NaN                   NaN
# 23                   NaN                   NaN
# 24                   NaN                   NaN
# 25                133.00                308.00
# 26                   NaN                   NaN
# 27                   NaN                   NaN
# 28                   NaN                   NaN
# 29                   NaN                   NaN
# 30                   NaN                   NaN
# 31                   NaN                   NaN

# %%
df = df.T

# %%
df.columns = ['매출액','영업이익','영업이익(발표기준)','세전계속사업이익',
              '당기순이익','당기순이익(지배)','당기순이익(비지배)','자산총계','부채총계',
              '자본총계','자본총계(지배)','자본총계(비지배)','자본금','영업활동현금흐름',
              '투자활동현금흐름','재무활동현금흐름','CAPEX', 'FCF', '이자발생부채',
              '영업이익률','순이익률','ROE(%)',
              'ROA(%)','부채비율','자본유보율','EPS(원)','PER(배)',
              'BPS(원)','PBR(배)','현금DPS(원)','현금배당수익률','현금배당성향(%)']

df
# Out:
#                         매출액  영업이익  영업이익(발표기준)  세전계속사업이익  당기순이익  당기순이익(지배)  \
# 주요재무정보                  매출액  영업이익  영업이익(발표기준)  세전계속사업이익  당기순이익  당기순이익(지배)
# 2019/09\n(IFRS연결)     14753   574         574       376    274        277
# 2019/12\n(IFRS연결)     15440   776         776       538    380        380
# 2020/03\n(IFRS연결)      9437  -668        -668      -925   -736       -736
# 2020/06\n(IFRS연결)      5230  -634        -634      -819   -677       -678
# 2020/09\n(IFRS연결)      8795  -198        -198      -366   -285       -285
# 2020/12(E)\n(IFRS연결)   9980    50         NaN      -109   -100       -100
# 2021/03(E)\n(IFRS연결)   9761   144         NaN        14     71         53
# 2021/06(E)\n(IFRS연결)   9820   265         NaN       172    214        123
#
#                       당기순이익(비지배)   자산총계   부채총계  자본총계  ...  ROA(%)    부채비율  \
# 주요재무정보                당기순이익(비지배)   자산총계   부채총계  자본총계  ...  ROA(%)    부채비율
# 2019/09\n(IFRS연결)             -3  37747  28854  8893  ...    3.62  324.45
# 2019/12\n(IFRS연결)              0  35273  26077  9195  ...    5.81  283.59
# 2020/03\n(IFRS연결)              0  33188  24813  8375  ...    1.25  296.28
# 2020/06\n(IFRS연결)              1  33039  25364  7676  ...   -2.14  330.45
# 2020/09\n(IFRS연결)              0  32683  25318  7365  ...   -3.74  343.77
# 2020/12(E)\n(IFRS연결)         NaN  32388  25171  7216  ...     NaN  348.79
# 2021/03(E)\n(IFRS연결)         NaN    NaN    NaN   NaN  ...     NaN     NaN
# 2021/06(E)\n(IFRS연결)         NaN    NaN    NaN   NaN  ...     NaN     NaN
#
#                        자본유보율  EPS(원)  PER(배)  BPS(원)  PBR(배)  현금DPS(원)  \
# 주요재무정보                 자본유보율  EPS(원)  PER(배)  BPS(원)  PBR(배)  현금DPS(원)
# 2019/09\n(IFRS연결)      395.1     692   31.19   23484    3.67         0
# 2019/12\n(IFRS연결)     411.78     950    21.4   24282    3.74       350
# 2020/03\n(IFRS연결)     368.36   -1839   63.76   22114    3.19       NaN
# 2020/06\n(IFRS연결)     334.46   -1695     NaN   20265     3.5       NaN
# 2020/09\n(IFRS연결)     320.21    -712     NaN   19444    3.91       NaN
# 2020/12(E)\n(IFRS연결)     NaN    -251     NaN   19187    4.22       NaN
# 2021/03(E)\n(IFRS연결)     NaN     133     NaN     NaN     NaN       NaN
# 2021/06(E)\n(IFRS연결)     NaN     308     NaN     NaN     NaN       NaN
#
#                       현금배당수익률  현금배당성향(%)
# 주요재무정보                현금배당수익률  현금배당성향(%)
# 2019/09\n(IFRS연결)         NaN          0
# 2019/12\n(IFRS연결)         NaN      34.94
# 2020/03\n(IFRS연결)         NaN          0
# 2020/06\n(IFRS연결)         NaN          0
# 2020/09\n(IFRS연결)         NaN        NaN
# 2020/12(E)\n(IFRS연결)      NaN        NaN
# 2021/03(E)\n(IFRS연결)      NaN        NaN
# 2021/06(E)\n(IFRS연결)      NaN        NaN
#
# [9 rows x 32 columns]

# %% [markdown]
# ## 2. 데이터 확인
#
# - 데이터의 dimension을 확인하세요.
# - 데이터의 결측치가 어디에 있는지 확인 후 0으로 대체하세요.
# - 각 데이터 별로 **FCF**의 값을 barplot으로 시각화하세요.
#   - 0보다 큰값, 작은값의 수의 총합을 `num1`, `num2`에 저장하세요

# %%
df.isnull().sum()
# Out:
# 매출액           0
# 영업이익          0
# 영업이익(발표기준)    3
# 세전계속사업이익      0
# 당기순이익         0
# 당기순이익(지배)     0
# 당기순이익(비지배)    3
# 자산총계          2
# 부채총계          2
# 자본총계          2
# 자본총계(지배)      2
# 자본총계(비지배)     3
# 자본금           2
# 영업활동현금흐름      3
# 투자활동현금흐름      3
# 재무활동현금흐름      3
# CAPEX         3
# FCF           3
# 이자발생부채        3
# 영업이익률         0
# 순이익률          0
# ROE(%)        3
# ROA(%)        3
# 부채비율          2
# 자본유보율         3
# EPS(원)        0
# PER(배)        5
# BPS(원)        2
# PBR(배)        2
# 현금DPS(원)      6
# 현금배당수익률       8
# 현금배당성향(%)     4
# dtype: int64

# %%
df.fillna(0, inplace=True)

# %%
df.isnull().sum()
# Out:
# 매출액           0
# 영업이익          0
# 영업이익(발표기준)    0
# 세전계속사업이익      0
# 당기순이익         0
# 당기순이익(지배)     0
# 당기순이익(비지배)    0
# 자산총계          0
# 부채총계          0
# 자본총계          0
# 자본총계(지배)      0
# 자본총계(비지배)     0
# 자본금           0
# 영업활동현금흐름      0
# 투자활동현금흐름      0
# 재무활동현금흐름      0
# CAPEX         0
# FCF           0
# 이자발생부채        0
# 영업이익률         0
# 순이익률          0
# ROE(%)        0
# ROA(%)        0
# 부채비율          0
# 자본유보율         0
# EPS(원)        0
# PER(배)        0
# BPS(원)        0
# PBR(배)        0
# 현금DPS(원)      0
# 현금배당수익률       0
# 현금배당성향(%)     0
# dtype: int64

# %%
pd.set_option('display.max_columns', None)
df
# Out:
#                         매출액  영업이익  영업이익(발표기준)  세전계속사업이익  당기순이익  당기순이익(지배)  \
# 주요재무정보                  매출액  영업이익  영업이익(발표기준)  세전계속사업이익  당기순이익  당기순이익(지배)
# 2019/09\n(IFRS연결)     14753   574         574       376    274        277
# 2019/12\n(IFRS연결)     15440   776         776       538    380        380
# 2020/03\n(IFRS연결)      9437  -668        -668      -925   -736       -736
# 2020/06\n(IFRS연결)      5230  -634        -634      -819   -677       -678
# 2020/09\n(IFRS연결)      8795  -198        -198      -366   -285       -285
# 2020/12(E)\n(IFRS연결)   9980    50           0      -109   -100       -100
# 2021/03(E)\n(IFRS연결)   9761   144           0        14     71         53
# 2021/06(E)\n(IFRS연결)   9820   265           0       172    214        123
#
#                       당기순이익(비지배)   자산총계   부채총계  자본총계  자본총계(지배)  자본총계(비지배)  \
# 주요재무정보                당기순이익(비지배)   자산총계   부채총계  자본총계  자본총계(지배)  자본총계(비지배)
# 2019/09\n(IFRS연결)             -3  37747  28854  8893      8889          4
# 2019/12\n(IFRS연결)              0  35273  26077  9195      9192          4
# 2020/03\n(IFRS연결)              0  33188  24813  8375      8371          4
# 2020/06\n(IFRS연결)              1  33039  25364  7676      7671          5
# 2020/09\n(IFRS연결)              0  32683  25318  7365      7360          5
# 2020/12(E)\n(IFRS연결)           0  32388  25171  7216      7263          0
# 2021/03(E)\n(IFRS연결)           0      0      0     0         0          0
# 2021/06(E)\n(IFRS연결)           0      0      0     0         0          0
#
#                        자본금  영업활동현금흐름  투자활동현금흐름  재무활동현금흐름  CAPEX   FCF  이자발생부채  \
# 주요재무정보                 자본금  영업활동현금흐름  투자활동현금흐름  재무활동현금흐름  CAPEX   FCF  이자발생부채
# 2019/09\n(IFRS연결)     2000      1652      -284      -900    159  1493   19035
# 2019/12\n(IFRS연결)     2000      -480      -208      1230    109  -589   15615
# 2020/03\n(IFRS연결)     2000     -4525      -237      1288    155 -4680   17505
# 2020/06\n(IFRS연결)     2000       879      -856       448     90   789   18933
# 2020/09\n(IFRS연결)     2000      3104     -1388      -882    129  2975   17755
# 2020/12(E)\n(IFRS연결)  2000         0         0         0      0     0       0
# 2021/03(E)\n(IFRS연결)     0         0         0         0      0     0       0
# 2021/06(E)\n(IFRS연결)     0         0         0         0      0     0       0
#
#                       영업이익률   순이익률  ROE(%)  ROA(%)    부채비율   자본유보율  EPS(원)  \
# 주요재무정보                영업이익률   순이익률  ROE(%)  ROA(%)    부채비율   자본유보율  EPS(원)
# 2019/09\n(IFRS연결)      3.89   1.86   13.18    3.62  324.45   395.1     692
# 2019/12\n(IFRS연결)      5.03   2.46   20.16    5.81  283.59  411.78     950
# 2020/03\n(IFRS연결)     -7.08   -7.8    5.39    1.25  296.28  368.36   -1839
# 2020/06\n(IFRS연결)    -12.13 -12.95   -9.31   -2.14  330.45  334.46   -1695
# 2020/09\n(IFRS연결)     -2.25  -3.24  -16.22   -3.74  343.77  320.21    -712
# 2020/12(E)\n(IFRS연결)    0.5  -1.01       0       0  348.79       0    -251
# 2021/03(E)\n(IFRS연결)   1.47   0.73       0       0       0       0     133
# 2021/06(E)\n(IFRS연결)    2.7   2.18       0       0       0       0     308
#
#                       PER(배)  BPS(원)  PBR(배)  현금DPS(원)  현금배당수익률  현금배당성향(%)
# 주요재무정보                PER(배)  BPS(원)  PBR(배)  현금DPS(원)  현금배당수익률  현금배당성향(%)
# 2019/09\n(IFRS연결)      31.19   23484    3.67         0        0          0
# 2019/12\n(IFRS연결)       21.4   24282    3.74       350        0      34.94
# 2020/03\n(IFRS연결)      63.76   22114    3.19         0        0          0
# 2020/06\n(IFRS연결)          0   20265     3.5         0        0          0
# 2020/09\n(IFRS연결)          0   19444    3.91         0        0          0
# 2020/12(E)\n(IFRS연결)       0   19187    4.22         0        0          0
# 2021/03(E)\n(IFRS연결)       0       0       0         0        0          0
# 2021/06(E)\n(IFRS연결)       0       0       0         0        0          0

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
s = df['FCF'].value_counts()
sns.barplot(x=s.index, y=s)
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9 entries, 주요재무정보 to 2021/06(E)
# (IFRS연결)
# Data columns (total 32 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   매출액         9 non-null      object
#  1   영업이익        9 non-null      object
#  2   영업이익(발표기준)  9 non-null      object
#  3   세전계속사업이익    9 non-null      object
#  4   당기순이익       9 non-null      object
#  5   당기순이익(지배)   9 non-null      object
#  6   당기순이익(비지배)  9 non-null      object
#  7   자산총계        9 non-null      object
#  8   부채총계        9 non-null      object
#  9   자본총계        9 non-null      object
#  10  자본총계(지배)    9 non-null      object
#  11  자본총계(비지배)   9 non-null      object
#  12  자본금         9 non-null      object
#  13  영업활동현금흐름    9 non-null      object
#  14  투자활동현금흐름    9 non-null      object
#  15  재무활동현금흐름    9 non-null      object
#  16  CAPEX       9 non-null      object
#  17  FCF         9 non-null      object
#  18  이자발생부채      9 non-null      object
#  19  영업이익률       9 non-null      object
#  20  순이익률        9 non-null      object
#  21  ROE(%)      9 non-null      object
#  22  ROA(%)      9 non-null      object
#  23  부채비율        9 non-null      object
#  24  자본유보율       9 non-null      object
#  25  EPS(원)      9 non-null      object
#  26  PER(배)      9 non-null      object
#  27  BPS(원)      9 non-null      object
#  28  PBR(배)      9 non-null      object
#  29  현금DPS(원)    9 non-null      object
#  30  현금배당수익률     9 non-null      object
#  31  현금배당성향(%)   9 non-null      object
# dtypes: object(32)
# memory usage: 2.6+ KB

# %%
df
# Out:
#                         매출액  영업이익  영업이익(발표기준)  세전계속사업이익  당기순이익  당기순이익(지배)  \
# 주요재무정보                  매출액  영업이익  영업이익(발표기준)  세전계속사업이익  당기순이익  당기순이익(지배)
# 2019/09\n(IFRS연결)     14753   574         574       376    274        277
# 2019/12\n(IFRS연결)     15440   776         776       538    380        380
# 2020/03\n(IFRS연결)      9437  -668        -668      -925   -736       -736
# 2020/06\n(IFRS연결)      5230  -634        -634      -819   -677       -678
# 2020/09\n(IFRS연결)      8795  -198        -198      -366   -285       -285
# 2020/12(E)\n(IFRS연결)   9980    50           0      -109   -100       -100
# 2021/03(E)\n(IFRS연결)   9761   144           0        14     71         53
# 2021/06(E)\n(IFRS연결)   9820   265           0       172    214        123
#
#                       당기순이익(비지배)   자산총계   부채총계  자본총계  자본총계(지배)  자본총계(비지배)  \
# 주요재무정보                당기순이익(비지배)   자산총계   부채총계  자본총계  자본총계(지배)  자본총계(비지배)
# 2019/09\n(IFRS연결)             -3  37747  28854  8893      8889          4
# 2019/12\n(IFRS연결)              0  35273  26077  9195      9192          4
# 2020/03\n(IFRS연결)              0  33188  24813  8375      8371          4
# 2020/06\n(IFRS연결)              1  33039  25364  7676      7671          5
# 2020/09\n(IFRS연결)              0  32683  25318  7365      7360          5
# 2020/12(E)\n(IFRS연결)           0  32388  25171  7216      7263          0
# 2021/03(E)\n(IFRS연결)           0      0      0     0         0          0
# 2021/06(E)\n(IFRS연결)           0      0      0     0         0          0
#
#                        자본금  영업활동현금흐름  투자활동현금흐름  재무활동현금흐름  CAPEX   FCF  이자발생부채  \
# 주요재무정보                 자본금  영업활동현금흐름  투자활동현금흐름  재무활동현금흐름  CAPEX   FCF  이자발생부채
# 2019/09\n(IFRS연결)     2000      1652      -284      -900    159  1493   19035
# 2019/12\n(IFRS연결)     2000      -480      -208      1230    109  -589   15615
# 2020/03\n(IFRS연결)     2000     -4525      -237      1288    155 -4680   17505
# 2020/06\n(IFRS연결)     2000       879      -856       448     90   789   18933
# 2020/09\n(IFRS연결)     2000      3104     -1388      -882    129  2975   17755
# 2020/12(E)\n(IFRS연결)  2000         0         0         0      0     0       0
# 2021/03(E)\n(IFRS연결)     0         0         0         0      0     0       0
# 2021/06(E)\n(IFRS연결)     0         0         0         0      0     0       0
#
#                       영업이익률   순이익률  ROE(%)  ROA(%)    부채비율   자본유보율  EPS(원)  \
# 주요재무정보                영업이익률   순이익률  ROE(%)  ROA(%)    부채비율   자본유보율  EPS(원)
# 2019/09\n(IFRS연결)      3.89   1.86   13.18    3.62  324.45   395.1     692
# 2019/12\n(IFRS연결)      5.03   2.46   20.16    5.81  283.59  411.78     950
# 2020/03\n(IFRS연결)     -7.08   -7.8    5.39    1.25  296.28  368.36   -1839
# 2020/06\n(IFRS연결)    -12.13 -12.95   -9.31   -2.14  330.45  334.46   -1695
# 2020/09\n(IFRS연결)     -2.25  -3.24  -16.22   -3.74  343.77  320.21    -712
# 2020/12(E)\n(IFRS연결)    0.5  -1.01       0       0  348.79       0    -251
# 2021/03(E)\n(IFRS연결)   1.47   0.73       0       0       0       0     133
# 2021/06(E)\n(IFRS연결)    2.7   2.18       0       0       0       0     308
#
#                       PER(배)  BPS(원)  PBR(배)  현금DPS(원)  현금배당수익률  현금배당성향(%)
# 주요재무정보                PER(배)  BPS(원)  PBR(배)  현금DPS(원)  현금배당수익률  현금배당성향(%)
# 2019/09\n(IFRS연결)      31.19   23484    3.67         0        0          0
# 2019/12\n(IFRS연결)       21.4   24282    3.74       350        0      34.94
# 2020/03\n(IFRS연결)      63.76   22114    3.19         0        0          0
# 2020/06\n(IFRS연결)          0   20265     3.5         0        0          0
# 2020/09\n(IFRS연결)          0   19444    3.91         0        0          0
# 2020/12(E)\n(IFRS연결)       0   19187    4.22         0        0          0
# 2021/03(E)\n(IFRS연결)       0       0       0         0        0          0
# 2021/06(E)\n(IFRS연결)       0       0       0         0        0          0

# %%
df.drop('주요재무정보')
# Out:
#                         매출액 영업이익 영업이익(발표기준) 세전계속사업이익 당기순이익 당기순이익(지배)  \
# 2019/09\n(IFRS연결)     14753  574        574      376   274       277
# 2019/12\n(IFRS연결)     15440  776        776      538   380       380
# 2020/03\n(IFRS연결)      9437 -668       -668     -925  -736      -736
# 2020/06\n(IFRS연결)      5230 -634       -634     -819  -677      -678
# 2020/09\n(IFRS연결)      8795 -198       -198     -366  -285      -285
# 2020/12(E)\n(IFRS연결)   9980   50          0     -109  -100      -100
# 2021/03(E)\n(IFRS연결)   9761  144          0       14    71        53
# 2021/06(E)\n(IFRS연결)   9820  265          0      172   214       123
#
#                      당기순이익(비지배)   자산총계   부채총계  자본총계 자본총계(지배) 자본총계(비지배)   자본금  \
# 2019/09\n(IFRS연결)            -3  37747  28854  8893     8889         4  2000
# 2019/12\n(IFRS연결)             0  35273  26077  9195     9192         4  2000
# 2020/03\n(IFRS연결)             0  33188  24813  8375     8371         4  2000
# 2020/06\n(IFRS연결)             1  33039  25364  7676     7671         5  2000
# 2020/09\n(IFRS연결)             0  32683  25318  7365     7360         5  2000
# 2020/12(E)\n(IFRS연결)          0  32388  25171  7216     7263         0  2000
# 2021/03(E)\n(IFRS연결)          0      0      0     0        0         0     0
# 2021/06(E)\n(IFRS연결)          0      0      0     0        0         0     0
#
#                      영업활동현금흐름 투자활동현금흐름 재무활동현금흐름 CAPEX   FCF 이자발생부채  영업이익률  \
# 2019/09\n(IFRS연결)        1652     -284     -900   159  1493  19035   3.89
# 2019/12\n(IFRS연결)        -480     -208     1230   109  -589  15615   5.03
# 2020/03\n(IFRS연결)       -4525     -237     1288   155 -4680  17505  -7.08
# 2020/06\n(IFRS연결)         879     -856      448    90   789  18933 -12.13
# 2020/09\n(IFRS연결)        3104    -1388     -882   129  2975  17755  -2.25
# 2020/12(E)\n(IFRS연결)        0        0        0     0     0      0    0.5
# 2021/03(E)\n(IFRS연결)        0        0        0     0     0      0   1.47
# 2021/06(E)\n(IFRS연결)        0        0        0     0     0      0    2.7
#
#                        순이익률 ROE(%) ROA(%)    부채비율   자본유보율 EPS(원) PER(배)  \
# 2019/09\n(IFRS연결)      1.86  13.18   3.62  324.45   395.1    692  31.19
# 2019/12\n(IFRS연결)      2.46  20.16   5.81  283.59  411.78    950   21.4
# 2020/03\n(IFRS연결)      -7.8   5.39   1.25  296.28  368.36  -1839  63.76
# 2020/06\n(IFRS연결)    -12.95  -9.31  -2.14  330.45  334.46  -1695      0
# 2020/09\n(IFRS연결)     -3.24 -16.22  -3.74  343.77  320.21   -712      0
# 2020/12(E)\n(IFRS연결)  -1.01      0      0  348.79       0   -251      0
# 2021/03(E)\n(IFRS연결)   0.73      0      0       0       0    133      0
# 2021/06(E)\n(IFRS연결)   2.18      0      0       0       0    308      0
#
#                      BPS(원) PBR(배) 현금DPS(원) 현금배당수익률 현금배당성향(%)
# 2019/09\n(IFRS연결)     23484   3.67        0       0         0
# 2019/12\n(IFRS연결)     24282   3.74      350       0     34.94
# 2020/03\n(IFRS연결)     22114   3.19        0       0         0
# 2020/06\n(IFRS연결)     20265    3.5        0       0         0
# 2020/09\n(IFRS연결)     19444   3.91        0       0         0
# 2020/12(E)\n(IFRS연결)  19187   4.22        0       0         0
# 2021/03(E)\n(IFRS연결)      0      0        0       0         0
# 2021/06(E)\n(IFRS연결)      0      0        0       0         0

# %%
df = df['FCF'].replace(',', '.', regex=True).astype(int)
df['FCF'] = pd.to_numeric(df['FCF'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-47-a19f3373b129> in <module>
# ----> 1 df = df['FCF'].replace(',', '.', regex=True).astype(int)
#       2 df['FCF'] = pd.to_numeric(df['FCF'])
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    5544         else:
#    5545             # else, only a single dtype is given
# -> 5546             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors,)
#    5547             return self._constructor(new_data).__finalize__(self, method="astype")
#    5548
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/internals/managers.py in astype(self, dtype, copy, errors)
#     593         self, dtype, copy: bool = False, errors: str = "raise"
#     594     ) -> "BlockManager":
# --> 595         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     596
#     597     def convert(
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/internals/managers.py in apply(self, f, align_keys, **kwargs)
#     404                 applied = b.apply(f, **kwargs)
#     405             else:
# --> 406                 applied = getattr(b, f)(**kwargs)
#     407             result_blocks = _extend_blocks(applied, result_blocks)
#     408
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/internals/blocks.py in astype(self, dtype, copy, errors)
#     593             vals1d = values.ravel()
#     594             try:
# --> 595                 values = astype_nansafe(vals1d, dtype, copy=True)
#     596             except (ValueError, TypeError):
#     597                 # e.g. astype_nansafe can fail on object-dtype of strings
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/dtypes/cast.py in astype_nansafe(arr, dtype, copy, skipna)
#     970         # work around NumPy brokenness, #1987
#     971         if np.issubdtype(dtype.type, np.integer):
# --> 972             return lib.astype_intsafe(arr.ravel(), dtype).reshape(arr.shape)
#     973
#     974         # if we have a datetime/timedelta array of objects
#
# pandas/_libs/lib.pyx in pandas._libs.lib.astype_intsafe()
#
# ValueError: invalid literal for int() with base 10: 'FCF'

# %%
df['FCF'].plot.bar()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-33-7b1143cd9878> in <module>
# ----> 1 df['FCF'].plot.bar()
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/plotting/_core.py in bar(self, x, y, **kwargs)
#    1105         other axis represents a measured value.
#    1106         """
# -> 1107         return self(kind="bar", x=x, y=y, **kwargs)
#    1108
#    1109     @Appender(
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/plotting/_core.py in __call__(self, *args, **kwargs)
#     947                     data.columns = label_name
#     948
# --> 949         return plot_backend.plot(data, kind=kind, **kwargs)
#     950
#     951     __call__.__doc__ = __doc__
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/plotting/_matplotlib/__init__.py in plot(data, kind, **kwargs)
#      59             kwargs["ax"] = getattr(ax, "left_ax", ax)
#      60     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 61     plot_obj.generate()
#      62     plot_obj.draw()
#      63     return plot_obj.result
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/plotting/_matplotlib/core.py in generate(self)
#     267     def generate(self):
#     268         self._args_adjust()
# --> 269         self._compute_plot_data()
#     270         self._setup_subplots()
#     271         self._make_plot()
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/plotting/_matplotlib/core.py in _compute_plot_data(self)
#     416         # no non-numeric frames or series allowed
#     417         if is_empty:
# --> 418             raise TypeError("no numeric data to plot")
#     419
#     420         # GH25587: cast ExtensionArray of pandas (IntegerArray, etc.) to
#
# TypeError: no numeric data to plot

# %% [markdown]
# ## 3. File export
#
# - 읽었던 엑셀 파일의 내용을 2개의 csv로 각각 출력하세요. (python export csv)
#
#   - 이름은 각각 `df1.csv`, `df2.csv` 입니다.

# %%
import xlrd
import csv

def csv_from_excel():
    wb = xlrd.open_workbook('Travel.xlsx')
    sh = wb.sheet_by_name('008770')
    your_csv_file = open('your_csv_file.csv', 'w')
    wr = csv.writer(your_csv_file, quoting=csv.QUOTE_ALL)

    for rownum in range(sh.nrows):
        wr.writerow(sh.row_values(rownum))

    your_csv_file.close()

# runs the csv_from_excel function:
csv_from_excel()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /opt/anaconda3/lib/python3.8/site-packages/xlrd/book.py in sheet_by_name(self, sheet_name)
#     473         try:
# --> 474             sheetx = self._sheet_names.index(sheet_name)
#     475         except ValueError:
#
# ValueError: '008770' is not in list
#
# During handling of the above exception, another exception occurred:
#
# XLRDError                                 Traceback (most recent call last)
# <ipython-input-31-a72c810d2240> in <module>
#      14
#      15 # runs the csv_from_excel function:
# ---> 16 csv_from_excel()
#
# <ipython-input-31-a72c810d2240> in csv_from_excel()
#       4 def csv_from_excel():
#       5     wb = xlrd.open_workbook('Travel.xlsx')
# ----> 6     sh = wb.sheet_by_name('008770')
#       7     your_csv_file = open('your_csv_file.csv', 'w')
#       8     wr = csv.writer(your_csv_file, quoting=csv.QUOTE_ALL)
#
# /opt/anaconda3/lib/python3.8/site-packages/xlrd/book.py in sheet_by_name(self, sheet_name)
#     474             sheetx = self._sheet_names.index(sheet_name)
#     475         except ValueError:
# --> 476             raise XLRDError('No sheet named <%r>' % sheet_name)
#     477         return self.sheet_by_index(sheetx)
#     478
#
# XLRDError: No sheet named <'008770'>

# %% [markdown]
# ## 4. Error Handling
#
# - 다음의 에러를 고치세요. 결과값은 6912가 나와야합니다.

# %%
a = 1234
b = 5678

a+b
# Out:
# 6912

# %% [markdown]
# ## 5. EDA
#
# 아래의 코드는 palmer penguin 데이터를 불러올 수 있는 코드입니다.
#
# ```python
# import seaborn as sns
#
# pp = sns.load_dataset('penguins')
# ```
#
# 이를 참조하여, `pp`의 `species`와 `sex`변수에 대해서 cross-tabulation을 시행하고, 6개의 값들 중 가장 큰 값을 `num3`에, 가장 작은 값을 `num4`에 저장하세요.

# %%
import seaborn as sns

# %% [markdown]
# ## Grading
#
# 이전 과제를 완료했다면, 아래의 코드를 실행하세요.

# %%
import os

def grade(df1, df2, num1, num2, num3, num4):
  score = 0
  
  score += (df1['매출액'][0] == 14753)
  score += (df2['매출액'][1] == 3728)

  score += (df1.shape == (7, 32))
  score += (df2.isnull().sum().sum() == 0)
  score += (num1 == 4 and num2 == 6)
  
  score += (num3 == 73 and num4 == 34)

  score += (os.listdir() == ['.config', 'df2.csv', 'df1.csv', 'sample_data'])

  score += (a+b == 6912)

  return(score)

# %%
grade(df1, df2, num1, num2, num3, num4)

# %% [markdown]
# ## 🔥 도전과제
#
# - 다음 데이터를 사용하여 아래와 동일한 그래프를 그리세요.
#
# <https://ds-lecture-data.s3.ap-northeast-2.amazonaws.com/stocks/TSLA.csv>
#
# <img src='https://i.imgur.com/UsS5JcZ.png'>

# %% [markdown]
# - penguins 데이터를 계속 사용합니다.
#
# 이에 대해 아래의 task들을 시행하세요.
#
# - 결측치 처리 (제거)
#
# - bill_length_mm에 대해서 qqplot 그리기
#
# - island에 대해서 다른 4개의 numerical feature 를 boxplot으로 표현하기
#
# - 각 numerical feature에 대해서 summary statistics : mean, sd, Quantiles(1Q, 2Q, 3Q, 4Q)를 계산하세요.
